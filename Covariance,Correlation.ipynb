# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_excel("data.xlsx")

# %%
data
# Out:
#     Price  Sale
# 0     205     3
# 1     150     5
# 2     300     8
# 3     450     5
# 4     410     6
# 5     350     4
# 6     456     6
# 7     254     1
# 8     140     2
# 9     369     8
# 10    268     7
# 11    138     6
# 12    321     4
# 13    100     2

# %%
data['Price'].cov(data['Sale'])
# Out:
# 120.62087912087912

# %%
plt.plot(data['Price'],data['Sale'])

# %%
plt.plot(data['Sale'],data['Price'])

# %%
plt.scatter(data['Price'],data['Sale'])

# %%
plt.scatter(data['Sale'],data['Price'])

# %%
data['Price']/data['Price'].max()
# Out:
# 0     0.449561
# 1     0.328947
# 2     0.657895
# 3     0.986842
# 4     0.899123
# 5     0.767544
# 6     1.000000
# 7     0.557018
# 8     0.307018
# 9     0.809211
# 10    0.587719
# 11    0.302632
# 12    0.703947
# 13    0.219298
# Name: Price, dtype: float64

# %%
plt.scatter((data['Price']/data['Price'].max()),(data['Sale']/data['Sale'].max())), plt.xlabel("Price"),plt.ylabel("Sale")
# Out:
# (<matplotlib.collections.PathCollection at 0x1acd6968f70>,
#  Text(0.5, 0, 'Price'),
#  Text(0, 0.5, 'Sale'))

# %%
x
# Out:
# (<matplotlib.collections.PathCollection at 0x1acd691c100>,
#  Text(0.5, 17.200000000000003, 'Price'),
#  Text(17.200000000000003, 0.5, 'Sale'))

# %%
data['Price'].corr(data['Sale'])
# Out:
# 0.45178970869342283

# %%
import pandas_datareader.data as web

# %%
all_data = {ticker: web.get_data_yahoo(ticker)
 for ticker in ['AAPL', 'IBM', 'MSFT', 'GOOG']}

# %%
price = pd.DataFrame({ticker: data['Adj Close']
 
                      for ticker, data in all_data.items()})

# %%
volume = pd.DataFrame({ticker: data['Volume']
                             for ticker, data in all_data.items()})

# %%
returns = price.pct_change()
returns
# Out:
#                 AAPL       IBM      MSFT      GOOG
# Date
# 2016-01-28       NaN       NaN       NaN       NaN
# 2016-01-29  0.034541  0.021028  0.058202  0.016403
# 2016-02-01 -0.009349  0.000321 -0.006898  0.012181
# 2016-02-02 -0.020222 -0.015141 -0.031256  0.016822
# 2016-02-03  0.019792  0.014479 -0.015849 -0.049304
# ...              ...       ...       ...       ...
# 2021-01-21  0.036658  0.012069  0.002808  0.002305
# 2021-01-22  0.016074 -0.099050  0.004356  0.005182
# 2021-01-25  0.027684 -0.000253  0.015844 -0.000868
# 2021-01-26  0.001679  0.032973  0.012199  0.009392
# 2021-01-27  0.003780  0.000490  0.032432 -0.028079
#
# [1259 rows x 4 columns]

# %%
returns['MSFT'].corr(returns['IBM'])
# Out:
# 0.5398021255386086

# %%
returns['MSFT'].cov(returns['IBM'])
# Out:
# 0.00015525546618948258

# %%
returns.corr()
# Out:
#           AAPL       IBM      MSFT      GOOG
# AAPL  1.000000  0.453736  0.712526  0.654004
# IBM   0.453736  1.000000  0.539802  0.503840
# MSFT  0.712526  0.539802  1.000000  0.774360
# GOOG  0.654004  0.503840  0.774360  1.000000

# %%
returns.cov()
# Out:
#           AAPL       IBM      MSFT      GOOG
# AAPL  0.000357  0.000141  0.000235  0.000205
# IBM   0.000141  0.000272  0.000155  0.000138
# MSFT  0.000235  0.000155  0.000304  0.000224
# GOOG  0.000205  0.000138  0.000224  0.000275

# %%
data= pd.read_excel(('data.xlsx'), header=0)
data
# Out:
#     Price  Sale
# 0     205     3
# 1     150     5
# 2     300     8
# 3     450     5
# 4     410     6
# 5     350     4
# 6     456     6
# 7     254     1
# 8     140     2
# 9     369     8
# 10    268     7
# 11    138     6
# 12    321     4
# 13    100     2

# %%
data= pd.read_excel(('data.xlsx'), sheet_name=1)
data
# Out:
#     205  3
# 0   150    5
# 1   300    8
# 2   450    5
# 3   410    6
# 4   350    4
# 5   456    6
# 6   254    1
# 7   140    2
# 8   369    8
# 9   268    7
# 10  138    6
# 11  321    4
# 12  100    2

# %%
data= pd.read_excel(('data.xlsx'), sheet_name=1, header=None,)
data
# Out:
#       0  1
# 0   205  3
# 1   150  5
# 2   300  8
# 3   450  5
# 4   410  6
# 5   350  4
# 6   456  6
# 7   254  1
# 8   140  2
# 9   369  8
# 10  268  7
# 11  138  6
# 12  321  4
# 13  100  2

# %%
data.rename(columns={0:'Price', 1:'Sales'})
# Out:
#     Price  Sales
# 0     205      3
# 1     150      5
# 2     300      8
# 3     450      5
# 4     410      6
# 5     350      4
# 6     456      6
# 7     254      1
# 8     140      2
# 9     369      8
# 10    268      7
# 11    138      6
# 12    321      4
# 13    100      2

# %%
result={'Student':['Ali','Ahmed','Taha','Furqan','Rizwan'],
        'English':[56,67,75,49,66],
        'Maths':  [77,47,78,90,82],
        'Science':[59,64,91,87,88]}
result
# Out:
# {'Student': ['Ali', 'Ahmed', 'Taha', 'Furqan', 'Rizwan'],
#  'English': [56, 67, 75, 49, 66],
#  'Maths': [77, 47, 78, 90, 82],
#  'Science': [59, 64, 91, 87, 88]}

# %%
result1=pd.DataFrame(result)

# %%
result1
# Out:
#   Student  English  Maths  Science
# 0     Ali       56     77       59
# 1   Ahmed       67     47       64
# 2    Taha       75     78       91
# 3  Furqan       49     90       87
# 4  Rizwan       66     82       88

# %%
result1.to_csv('Result.csv')

# %%
import requests

# %%
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'

# %%
resp = requests.get(url)

# %%
resp
# Out:
# <Response [200]>

# %%
data = resp.json()

# %%
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39435',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39435/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39435/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39435/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/39435',
#   'id': 795033311,
#   'node_id': 'MDU6SXNzdWU3OTUwMzMzMTE=',
#   'number': 39435,
#   'title': 'ENH: support reading from several files for read_* functions',
#   'user': {'login': 'anmyachev',
#    'id': 45976948,
#    'node_id': 'MDQ6VXNlcjQ1OTc2OTQ4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45976948?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/anmyachev',
#    'html_url': 'https://github.com/anmyachev',
# ...

# %%
data[0]['title']
# Out:
# 'ENH: support reading from several files for read_* functions'

# %%
len(data)
# Out:
# 30

# %%
len(data[0])
# Out:
# 25

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
df.columns
# Out:
# Index(['url', 'repository_url', 'labels_url', 'comments_url', 'events_url',
#        'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels',
#        'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments',
#        'created_at', 'updated_at', 'closed_at', 'author_association',
#        'active_lock_reason', 'body', 'performed_via_github_app',
#        'pull_request'],
#       dtype='object')

# %%
df['user']
# Out:
# 0     {'login': 'anmyachev', 'id': 45976948, 'node_i...
# 1     {'login': 'YarShev', 'id': 26389732, 'node_id'...
# 2     {'login': 'derHeinzer', 'id': 43210452, 'node_...
# 3     {'login': 'bashtage', 'id': 5585221, 'node_id'...
# 4     {'login': 'ihafsa', 'id': 45327103, 'node_id':...
# 5     {'login': 'thoo', 'id': 6972290, 'node_id': 'M...
# 6     {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 7     {'login': 'gshimansky', 'id': 11276794, 'node_...
# 8     {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 9     {'login': 'attack68', 'id': 24256554, 'node_id...
# 10    {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 11    {'login': 'MichalHeydelQC', 'id': 41172676, 'n...
# 12    {'login': 'attack68', 'id': 24256554, 'node_id...
# 13    {'login': 'nofarm3', 'id': 8852168, 'node_id':...
# 14    {'login': 'nolanbconaway', 'id': 1770896, 'nod...
# 15    {'login': 'fangchenli', 'id': 7614606, 'node_i...
# 16    {'login': 'fangchenli', 'id': 7614606, 'node_i...
# ...

# %%
users=pd.DataFrame(df, columns=['user', 'labels',
       'state', 'locked', 'assignee', 'assignees',])

# %%
len(users)
# Out:
# 30

# %%
type(users['user'])
# Out:
# pandas.core.series.Series

# %%
users
# Out:
#                                                  user  \
# 0   {'login': 'anmyachev', 'id': 45976948, 'node_i...
# 1   {'login': 'YarShev', 'id': 26389732, 'node_id'...
# 2   {'login': 'derHeinzer', 'id': 43210452, 'node_...
# 3   {'login': 'bashtage', 'id': 5585221, 'node_id'...
# 4   {'login': 'ihafsa', 'id': 45327103, 'node_id':...
# 5   {'login': 'thoo', 'id': 6972290, 'node_id': 'M...
# 6   {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 7   {'login': 'gshimansky', 'id': 11276794, 'node_...
# 8   {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 9   {'login': 'attack68', 'id': 24256554, 'node_id...
# 10  {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 11  {'login': 'MichalHeydelQC', 'id': 41172676, 'n...
# 12  {'login': 'attack68', 'id': 24256554, 'node_id...
# 13  {'login': 'nofarm3', 'id': 8852168, 'node_id':...
# 14  {'login': 'nolanbconaway', 'id': 1770896, 'nod...
# 15  {'login': 'fangchenli', 'id': 7614606, 'node_i...
# ...
